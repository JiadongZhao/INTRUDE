# %%
# %run -i 'clf.py'
# %matplotlib inline
# Out:
# text_sim_type = lsi
# code_sim_type = tfidf
# extract_sim_type = ori_and_overlap
# Model Data Save Path =  ok_text_lsi_code_tfidf_ori_and_overlap__commit_message
# --------------------------
# Loading Data
# Model Data Input= data/clf/first_msr_pairs.txt
# ...
# Model Data Input= data/clf/second_msr_pairs.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_training.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_testing.txt
# ...
# --------------------------
# Size of Dataset: training_set 103293 testing_set 105431 feature_length= 10
# ------ model:  boost ------
# Mean Accuracy: 0.9910367918354184
# Average precision score: 0.5375
# F1 score: 0.5249
# 0.9910367918354184	0.5374660874579056	0.5248868778280542

# %%
### gradient boosting
# %run -i 'clf.py'
# %matplotlib inline
# Out:
# text_sim_type = lsi
# code_sim_type = tfidf
# extract_sim_type = ori_and_overlap
# Model Data Save Path =  ok_text_lsi_code_tfidf_ori_and_overlap__commit_message
# --------------------------
# Loading Data
# Model Data Input= data/clf/first_msr_pairs.txt
# ...
# Model Data Input= data/clf/second_msr_pairs.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_training.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_testing.txt
# ...
# --------------------------
# Size of Dataset: training_set 103293 testing_set 105431 feature_length= 10
# ------ model:  boost ------
# Mean Accuracy: 0.9910083372063245
# Average precision score: 0.5120
# F1 score: 0.5344
# 0.9910083372063245	0.5120141457336703	0.5343811394891946

# %%
### gradient boosting
# %run -i 'clf.py'
# %matplotlib inline
# Out:
# text_sim_type = lsi
# code_sim_type = tfidf
# extract_sim_type = ori_and_overlap
# Model Data Save Path =  ok_text_lsi_code_tfidf_ori_and_overlap__commit_message
# --------------------------
# Loading Data
# Model Data Input= data/clf/first_msr_pairs.txt
# ...
# Model Data Input= data/clf/second_msr_pairs.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_training.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_testing.txt
# ...
# --------------------------
# Size of Dataset: training_set 103293 testing_set 105431 feature_length= 10
# ------ model:  boost ------
# Mean Accuracy: 0.9890829073043033
# Average precision score: 0.5434
# F1 score: 0.5885
# 0.9890829073043033	0.5433695887991762	0.5884876653557383

# %%
### smote k_neighbor = 15
# %run -i 'clf.py'
# %matplotlib inline
# Out:
# text_sim_type = lsi
# code_sim_type = tfidf
# extract_sim_type = ori_and_overlap
# Model Data Save Path =  ok_text_lsi_code_tfidf_ori_and_overlap__commit_message
# --------------------------
# Loading Data
# Model Data Input= data/clf/first_msr_pairs.txt
# ...
# Model Data Input= data/clf/second_msr_pairs.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_training.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_testing.txt
# ...
# --------------------------
# Size of Dataset: training_set 103293 testing_set 105431 feature_length= 10
# ------ model:  boost ------
# Mean Accuracy: 0.9698665477895496
# Average precision score: 0.5189
# F1 score: 0.3889
# 0.9698665477895496	0.5188622776261663	0.3889209463358338

# %%
### pos*5
# %run -i 'clf.py'
# %matplotlib inline
# Out:
# text_sim_type = lsi
# code_sim_type = tfidf
# extract_sim_type = ori_and_overlap
# Model Data Save Path =  ok_text_lsi_code_tfidf_ori_and_overlap__commit_message
# --------------------------
# Loading Data
# Model Data Input= data/clf/first_msr_pairs.txt
# ...
# Model Data Input= data/clf/second_msr_pairs.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_training.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_testing.txt
# ...
# --------------------------
# Size of Dataset: training_set 103293 testing_set 105431 feature_length= 10
# ------ model:  boost ------
# Mean Accuracy: 0.9890829073043033
# Average precision score: 0.5434
# F1 score: 0.5885
# 0.9890829073043033	0.5433695887991762	0.5884876653557383

# %%
## adaboost updated model
# %run -i 'rq1_parse.py'
# Out:
# 0.1346	0.6260869565217392	0.9817232375979112
# 0.1356	0.6260869565217392	0.9817232375979112
# 0.1366	0.6260869565217392	0.9817232375979112
# 0.1376	0.6260869565217392	0.9817232375979112
# 0.1386	0.6260869565217392	0.9817232375979112
# 0.1396	0.6260869565217392	0.9817232375979112
# 0.1406	0.6260869565217392	0.9817232375979112
# 0.1416	0.6260869565217392	0.9808529155787642
# 0.1426	0.6260869565217392	0.9808529155787642
# 0.1436	0.6260869565217392	0.9808529155787642
# 0.1446	0.6260869565217392	0.9808529155787642
# 0.1456	0.6260869565217392	0.979982593559617
# 0.1466	0.6260869565217392	0.979982593559617
# 0.1476	0.6260869565217392	0.979982593559617
# 0.1486	0.6260869565217392	0.979982593559617
# 0.1496	0.6260869565217392	0.979982593559617
# 0.1506	0.6260869565217392	0.979982593559617
# 0.1516	0.6260869565217392	0.979982593559617
# 0.1526	0.6260869565217392	0.979982593559617
# 0.1536	0.6260869565217392	0.979982593559617
# 0.1546	0.6260869565217392	0.979982593559617
# ...

# %%
## 116 pairs updated model
# %run -i 'rq1_parse.py'
# Out:
# 0.1346	0.375	0.9817232375979112
# 0.1356	0.375	0.9817232375979112
# 0.1366	0.375	0.9817232375979112
# 0.1376	0.375	0.9817232375979112
# 0.1386	0.375	0.9817232375979112
# 0.1396	0.375	0.9817232375979112
# 0.1406	0.375	0.9817232375979112
# 0.1416	0.375	0.9808529155787642
# 0.1426	0.375	0.9808529155787642
# 0.1436	0.375	0.9808529155787642
# 0.1446	0.375	0.9808529155787642
# 0.1456	0.375	0.979982593559617
# 0.1466	0.375	0.979982593559617
# 0.1476	0.375	0.979982593559617
# 0.1486	0.375	0.979982593559617
# 0.1496	0.375	0.979982593559617
# 0.1506	0.375	0.979982593559617
# 0.1516	0.375	0.979982593559617
# 0.1526	0.375	0.979982593559617
# 0.1536	0.375	0.979982593559617
# 0.1546	0.375	0.979982593559617
# 0.1556	0.375	0.97911227154047
# 0.1566	0.375	0.97911227154047
# 0.1576	0.375	0.97911227154047
# 0.1586	0.375	0.97911227154047
# 0.1596	0.375	0.9782419495213229
# 0.1606	0.375	0.9782419495213229
# 0.1616	0.375	0.9782419495213229
# 0.1626	0.375	0.9782419495213229
# ...

# %%
### gbdt n-200 r-0.01 d-5
# %run -i 'clf.py'
# %matplotlib inline
# Out:
# text_sim_type = lsi
# code_sim_type = tfidf
# extract_sim_type = ori_and_overlap
# Model Data Save Path =  ok_text_lsi_code_tfidf_ori_and_overlap__commit_message
# --------------------------
# Loading Data
# Model Data Input= data/clf/first_msr_pairs.txt
# ...
# Model Data Input= data/clf/second_msr_pairs.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_training.txt
# ...
# Model Data Input= data/clf/consecutive_NonDupPR_pairs_testing.txt
# ...
# --------------------------
# Size of Dataset: training_set 103293 testing_set 105431 feature_length= 10
# ------ model:  boost ------
# n_estimators: 25 max_depth: 2
# 0.9886342741104764
# Mean Accuracy: 0.9891018770570326
# Average precision score: 0.4272
# F1 score: 0.0000
# 0.9891018770570326	0.42721594394658097	0.0
# /home/feature/.local/lib/python3.4/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
# ...
